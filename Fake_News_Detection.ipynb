# %%
#@title Installation
# !pip install transformers

# %%
#@title Module Imports
import io,os
import pandas as pd
import csv
import json
import torch
from sklearn.model_selection import train_test_split
from torch.nn import Module,\
                     ModuleList,\
                     Linear,\
                     Sigmoid,\
                     BCELoss
import torch.nn.functional as F
from torch.optim import Adam
from transformers import BertTokenizer,\
                         BertModel
                        #  LongformerModel,\
                        #  LongformerTokenizer

# %%
#@title Dataset Download { form-width: "15%" }
kaggle_json = {"username":"masoudmousavi","key":"c94c66490147612c6fc696e81c98d771"}
os.makedirs('/content/.kaggle/',exist_ok=True)
os.makedirs('/root/.kaggle/',exist_ok=True)
with open('/content/.kaggle/kaggle.json', 'w') as file:
  json.dump(kaggle_json, file)
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
! kaggle competitions download -c fake-news
! unzip /content/train.csv.zip 
! rm -rf /content/train.csv.zip
! unzip /content/test.csv.zip 
! rm -rf /content/test.csv.zip

# %%
#@title Device Config
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device is {device}')
# Out:
# Device is cuda

# %%
#@title Dataset Load and Preprocessing { form-width: "15%" }
DEV_SET_SIZE = 6400
_train_df = pd.read_csv("train.csv")
_train_df = _train_df.sample(frac=1)
train_df, dev_df = train_test_split(_train_df, test_size = DEV_SET_SIZE) 
_train_df = None
test_df = pd.read_csv("test.csv")
submit_df = pd.read_csv("submit.csv")

# %%
train_df

# %%
#@title Encoder Models and Tokenizers { form-width: "15%" }
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_encoder = BertModel.from_pretrained('bert-base-uncased', output_hidden_states=True)
bert_encoder.to(device)

# lf_encoder = LongformerModel.from_pretrained('allenai/longformer-base-4096', output_hidden_states=True)
# lf_tokenizer = LongformerTokenizer.from_pretrained('allenai/longformer-base-4096')
# lf_encoder.to(device)

# %%
#@title Neural Network { form-width: "15%" }
class NeuralNet(Module):
  def __init__(self, fully_connected_dims, dropout, input_size=768):
    super().__init__()
    self.dropout = dropout
    self.input_size = input_size
    fc_list = [Linear(self.input_size, fully_connected_dims[0])] +\
              [Linear(fully_connected_dims[i], fully_connected_dims[i+1])
               for i in range(len(fully_connected_dims[:-1] ))
              ] +\
              [
               Linear(fully_connected_dims[-1], 1)
              ]
    self.fc_layers = ModuleList(fc_list)
    self.classifier = Sigmoid()

  def forward(self, x):
    h = x
    for fc in self.fc_layers[:-1]:
      h = fc(h)
      h = F.relu(h)
      if self.training:
        h = F.dropout(h, p=self.dropout)
    
    h = self.fc_layers[-1](h)
    if self.training:
      h = F.dropout(h, p=self.dropout)
    h = self.classifier(h)
    return h

# %%
#@title Model and Hyperparameters
model = NeuralNet((128, 128), 0.4)
model.to(device)
print(model)
mini_batch_size = 128
n_epochs = 250
optimizer = Adam(model.parameters(), lr=1e-3)
criterion = BCELoss()

# %%
#@title bert_batch_maker(df) { form-width: "15%" }
def bert_batch_maker(df, batch_name):
  from collections import defaultdict
  tokens_by_len = defaultdict(list)
  labels_by_len = defaultdict(list)
  encodings = list()
  labels = list()

  tokens_list = dict()
  i = 0
  for row in df.iterrows():
    i += 1

    id, title, author, text, label = row[1]
    
    cpu_device = 'cpu'
    
    part1_masked_sentence = f'[CLS] {title} [SEP] {author} [SEP] '
    part1_tokens = bert_tokenizer.tokenize(part1_masked_sentence)
    part1_sentence_size = len(part1_tokens)

    part2_masked_sentence = f'{text} [SEP]'
    part2_tokens = bert_tokenizer.tokenize(part2_masked_sentence)
    part2_sentence_size = len(part2_tokens)

    if part2_sentence_size + part1_sentence_size > 512:
      truncate_len = 512 - 1 - part1_sentence_size
      truncated_part2_tokens = part2_tokens[:truncate_len] + [part2_tokens[-1]]
      tokens = part1_tokens + truncated_part2_tokens
    else:
      tokens = part1_tokens + part2_tokens

    indexed_tokens = bert_tokenizer.convert_tokens_to_ids(tokens)
    tokens_tensor = torch.tensor([indexed_tokens], device=device) 

    bert_encoder.eval()
    batch_id = 0
    with torch.no_grad():
        outputs = bert_encoder(tokens_tensor)
        bert_hidden_states = outputs[2]
        z_encoding = torch.stack(bert_hidden_states[-4:]).sum(dim=0) # sum of last four layers
        
        cls_encoding = z_encoding[0, 0].reshape(1, -1)

        
        cls_encoding = torch.tensor(cls_encoding, device='cpu')
        print(f'Sentence {i} of {" ".join(list(map(str.capitalize, batch_name.split(" "))))}, Bert Encoding...')
        # batch_id += 1
        encodings.append(cls_encoding)
        labels.append(torch.tensor(label, dtype=torch.float, device='cpu'))
        

  batch_encodings = torch.stack(encodings)
  batch_labels = torch.stack(labels)

  return batch_encodings, batch_labels

# %%
#@title batch_maker_method2(df) INCOMPLETE { form-width: "15%" }
def batch_maker_method2(df):
  from collections import defaultdict
  tokens_by_len = defaultdict(list)
  labels_by_len = defaultdict(list)
  encodings = list()
  labels = list()

  tokens_list = dict()
  i = 0
  for row in df.iterrows():

    id, title, author, text, label = row[1]
    labels.append(label)
    cpu_device = 'cpu'
    
    part1_masked_sentence = f'[CLS] {title} [SEP] {author} [SEP] '
    part1_tokens = bert_tokenizer.tokenize(part1_masked_sentence)
    part1_sentence_size = len(part1_tokens)

    part2_masked_sentence = f'{text} [SEP]'
    part2_tokens = bert_tokenizer.tokenize(part2_masked_sentence)
    part2_sentence_size = len(part2_tokens)

    if part2_sentence_size + part1_sentence_size > 512:
      truncate_len = 512 - 1 - part1_sentence_size
      truncated_part2_tokens = part2_tokens[:truncate_len] + [part2_tokens[-1]]
      tokens = part1_tokens + truncated_part2_tokens
    else:
      tokens = part1_tokens + part2_tokens

    indexed_tokens = bert_tokenizer.convert_tokens_to_ids(tokens)
    tokens_tensor = torch.tensor([indexed_tokens], device=device) 

    bert_encoder.eval()
    batch_id = 0
    with torch.no_grad():
        outputs = bert_encoder(tokens_tensor)
        bert_hidden_states = outputs[2]
        z_encoding = torch.stack(bert_hidden_states[-4:]).sum(dim=0) # sum of last four layers
        
        cls_encoding = z_encoding[0, 0].reshape(1, -1)

        
        cls_encoding = torch.tensor(cls_encoding, device='cpu')
        print(f'Sentence {id}, Bert Encoding...')
        # batch_id += 1
        encodings.append(cls_encoding)
        labels.append(torch.tensor(label, dtype=torch.float, device='cpu'))
        

  









    
  #   # indexed_tokens = bert_tokenizer.convert_tokens_to_ids(tokens)
  #   # tokens_tensor = torch.tensor([indexed_tokens], device=device) 
    
  #   tokens_list.update({i:tokens})
  #   i += 1
  #   # labels.append(torch.tensor(label, dtype=torch.float, device=cpu_device))
  #   # print(label)
  #   # print(f'Sentence {id + 1}, Bert Encoding...')
  #   # print(label)
  
  # for id, token_list in tokens_list.items():
  #   # print(tl.__class__.__name__)
  #   ########################################################### 
  #   # print(zip(tl))
  #   # id, token_list = list(tl)
  #   tokens_by_len[len(token_list)].append(token_list)
  #   labels_by_len[len(token_list)].append(labels[id])
  #   ########################################################### 
    
  # # print(labels_by_len.items())
  # # return
  # labels = list()
  # for _len_key, _tokens_list in tokens_by_len.items(): 
  #   indices_list = list()
  #   for sentence_tokens in _tokens_list:
  #     ids = bert_tokenizer.convert_tokens_to_ids(sentence_tokens)
  #     indices_list.append(torch.tensor(ids, device=device))
  #   indices_tensors = torch.stack(indices_list)
  #   labels.append(labels_by_len[_len_key])
  #   # print(indices_tensors.shape)

  #   bert_encoder.eval()
  #   batch_id = 0
  #   with torch.no_grad():
  #       outputs = bert_encoder(indices_tensors)

  #       # print(outputs[2].shape)

  #       bert_hidden_states = outputs[2]
  #       z_encodings = torch.stack(bert_hidden_states[-4:]).sum(dim=0) # sum of last four layers
        
  #       cls_encodings = z_encodings[:, 0]
        
  #       cls_encodings = torch.tensor(cls_encodings, device=cpu_device)
  #       print(f'Batch {batch_id + 1}, Bert Encoding Size {cls_encodings.shape[0]}...')
  #       batch_id += 1
  #       encodings.append(cls_encodings)
  #       # labels.append(torch.tensor(label, dtype=torch.float, device=device))
        

  # # batch_encodings = torch.stack(encodings)
  # # batch_labels = torch.stack(labels)

  # return encodings, labels

# %%
#@title train(model, x, y, optimizer, loss_fn)
def train(model, x, y, optimizer, loss_fn):
  batch_loss = 0

  model.train()

  out = model(x)
  optimizer.zero_grad()
  loss = loss_fn(out.reshape(-1), y)
  batch_loss = loss.item()
  loss.backward()
  optimizer.step()

  prediction = torch.round(out)
  correct = torch.tensor(
      (prediction.reshape(-1) == y),
      dtype=torch.int, device=device).sum().item()

  return batch_loss, correct

# %%
#@title evaluate(model, x, y)
@torch.no_grad()
def evaluate(model, x, y):
  model.eval()

  out = model(x)
  prediction = torch.round(out)
  correct = torch.tensor(
      (prediction.reshape(-1) == y),
      dtype=torch.int, device=device).sum().item()

  model.train()
  return correct

# %%
#@title BERT Batch Maker
h_train, y_train = bert_batch_maker(train_df, 'train set')
h_dev, y_dev = bert_batch_maker(dev_df, 'dev set')

# %%
#@title NN Fitting { form-width: "15%" }
i = 0

batch_loss = 0

for epoch in range(n_epochs):
  loss = 0
  correct = 0
  for batch in range(mini_batch_size, h_train.shape[0], mini_batch_size):
    X = h_train[batch - mini_batch_size:batch, :, :]
    X = X.to(device)
  
    y = y_train[batch - mini_batch_size:batch]
    y = y.to(device)



    model.train()
    batch_loss, batch_correct = train(model, X, y, optimizer, criterion)
    loss += batch_loss
    correct += batch_correct
  
  model.eval()
  X = h_dev.to(device)
  y = y_dev.to(device)
  dev_correct = evaluate(model, X, y)
  # model.train()
  print(f'{"=" * 32} Epoch {epoch + 1} {"=" * 32}')
  print(f'Epoch Loss: {loss}')
  print(f'Train Accuracy: {correct / h_train.shape[0] * 100:.3f} %')
  print(f'Dev Accuracy:  {dev_correct / h_dev.shape[0] * 100:.3f} %')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.
# ================================ Epoch 1 ================================
# Epoch Loss: 37.37760230898857
# Train Accuracy: 77.507 %
# Dev Accuracy:  98.172 %
# ================================ Epoch 2 ================================
# Epoch Loss: 36.039905443787575
# Train Accuracy: 78.069 %
# Dev Accuracy:  98.297 %
# ================================ Epoch 3 ================================
# Epoch Loss: 36.14202120900154
# Train Accuracy: 78.021 %
# Dev Accuracy:  97.578 %
# ================================ Epoch 4 ================================
# Epoch Loss: 36.58903504908085
# Train Accuracy: 78.194 %
# Dev Accuracy:  97.859 %
# ================================ Epoch 5 ================================
# Epoch Loss: 36.414849892258644
# Train Accuracy: 77.694 %
# Dev Accuracy:  98.109 %
# ================================ Epoch 6 ================================
# Epoch Loss: 35.94998079538345
# Train Accuracy: 78.146 %
# Dev Accuracy:  97.594 %
# ================================ Epoch 7 ================================
# Epoch Loss: 36.1414158642292
# Train Accuracy: 77.875 %
# Dev Accuracy:  97.938 %
# ================================ Epoch 8 ================================
# Epoch Loss: 35.882567688822746
# Train Accuracy: 78.243 %
# Dev Accuracy:  98.031 %
# ================================ Epoch 9 ================================
# Epoch Loss: 35.944834530353546
# Train Accuracy: 78.049 %
# Dev Accuracy:  96.922 %
# ================================ Epoch 10 ================================
# Epoch Loss: 36.55700930953026
# Train Accuracy: 78.007 %
# Dev Accuracy:  98.250 %
# ================================ Epoch 11 ================================
# Epoch Loss: 35.979854732751846
# Train Accuracy: 77.875 %
# Dev Accuracy:  98.000 %
# ================================ Epoch 12 ================================
# Epoch Loss: 35.53332667052746
# Train Accuracy: 78.368 %
# Dev Accuracy:  98.047 %
# ================================ Epoch 13 ================================
# Epoch Loss: 36.87261524796486
# Train Accuracy: 77.667 %
# Dev Accuracy:  97.281 %
# ================================ Epoch 14 ================================
# Epoch Loss: 35.82798124849796
# Train Accuracy: 78.125 %
# Dev Accuracy:  98.172 %
# ================================ Epoch 15 ================================
# Epoch Loss: 35.593075066804886
# Train Accuracy: 78.312 %
# Dev Accuracy:  98.234 %
# ================================ Epoch 16 ================================
# Epoch Loss: 36.16292317211628
# Train Accuracy: 77.944 %
# Dev Accuracy:  98.016 %
# ================================ Epoch 17 ================================
# Epoch Loss: 36.47915489971638
# Train Accuracy: 77.847 %
# Dev Accuracy:  98.406 %
# ================================ Epoch 18 ================================
# Epoch Loss: 36.300055384635925
# Train Accuracy: 77.715 %
# Dev Accuracy:  97.609 %
# ================================ Epoch 19 ================================
# Epoch Loss: 36.124307334423065
# Train Accuracy: 77.958 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 20 ================================
# Epoch Loss: 36.01383601129055
# Train Accuracy: 77.812 %
# Dev Accuracy:  97.609 %
# ================================ Epoch 21 ================================
# Epoch Loss: 36.28301785886288
# Train Accuracy: 77.722 %
# Dev Accuracy:  97.688 %
# ================================ Epoch 22 ================================
# Epoch Loss: 36.64716251194477
# Train Accuracy: 77.618 %
# Dev Accuracy:  97.781 %
# ================================ Epoch 23 ================================
# Epoch Loss: 36.206152245402336
# Train Accuracy: 78.167 %
# Dev Accuracy:  97.594 %
# ================================ Epoch 24 ================================
# Epoch Loss: 36.108538806438446
# Train Accuracy: 78.062 %
# Dev Accuracy:  97.844 %
# ================================ Epoch 25 ================================
# Epoch Loss: 35.70703434944153
# Train Accuracy: 78.382 %
# Dev Accuracy:  97.062 %
# ================================ Epoch 26 ================================
# Epoch Loss: 35.92543904483318
# Train Accuracy: 77.833 %
# Dev Accuracy:  96.953 %
# ================================ Epoch 27 ================================
# Epoch Loss: 35.3843694627285
# Train Accuracy: 78.188 %
# Dev Accuracy:  97.828 %
# ================================ Epoch 28 ================================
# Epoch Loss: 36.086957305669785
# Train Accuracy: 77.819 %
# Dev Accuracy:  97.203 %
# ================================ Epoch 29 ================================
# Epoch Loss: 36.188823476433754
# Train Accuracy: 77.986 %
# Dev Accuracy:  97.781 %
# ================================ Epoch 30 ================================
# Epoch Loss: 35.87136322259903
# Train Accuracy: 78.042 %
# Dev Accuracy:  97.797 %
# ================================ Epoch 31 ================================
# Epoch Loss: 36.27682089805603
# Train Accuracy: 77.549 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 32 ================================
# Epoch Loss: 36.12059377133846
# Train Accuracy: 78.306 %
# Dev Accuracy:  97.750 %
# ================================ Epoch 33 ================================
# Epoch Loss: 36.131798177957535
# Train Accuracy: 77.326 %
# Dev Accuracy:  97.578 %
# ================================ Epoch 34 ================================
# Epoch Loss: 36.069567650556564
# Train Accuracy: 77.868 %
# Dev Accuracy:  97.812 %
# ================================ Epoch 35 ================================
# Epoch Loss: 36.15170831978321
# Train Accuracy: 77.660 %
# Dev Accuracy:  97.906 %
# ================================ Epoch 36 ================================
# Epoch Loss: 36.44680792093277
# Train Accuracy: 78.062 %
# Dev Accuracy:  97.719 %
# ================================ Epoch 37 ================================
# Epoch Loss: 36.79571223258972
# Train Accuracy: 77.681 %
# Dev Accuracy:  97.516 %
# ================================ Epoch 38 ================================
# Epoch Loss: 36.864873349666595
# Train Accuracy: 77.542 %
# Dev Accuracy:  97.859 %
# ================================ Epoch 39 ================================
# Epoch Loss: 35.97595497965813
# Train Accuracy: 78.451 %
# Dev Accuracy:  97.766 %
# ================================ Epoch 40 ================================
# Epoch Loss: 36.811907321214676
# Train Accuracy: 77.535 %
# Dev Accuracy:  96.234 %
# ================================ Epoch 41 ================================
# Epoch Loss: 36.43368203938007
# Train Accuracy: 77.903 %
# Dev Accuracy:  97.047 %
# ================================ Epoch 42 ================================
# Epoch Loss: 35.500120520591736
# Train Accuracy: 77.847 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 43 ================================
# Epoch Loss: 37.27123114466667
# Train Accuracy: 77.646 %
# Dev Accuracy:  97.734 %
# ================================ Epoch 44 ================================
# Epoch Loss: 36.98760053515434
# Train Accuracy: 77.694 %
# Dev Accuracy:  97.016 %
# ================================ Epoch 45 ================================
# Epoch Loss: 36.759482488036156
# Train Accuracy: 77.618 %
# Dev Accuracy:  97.547 %
# ================================ Epoch 46 ================================
# Epoch Loss: 36.15693116188049
# Train Accuracy: 78.049 %
# Dev Accuracy:  96.906 %
# ================================ Epoch 47 ================================
# Epoch Loss: 36.055728018283844
# Train Accuracy: 77.764 %
# Dev Accuracy:  97.578 %
# ================================ Epoch 48 ================================
# Epoch Loss: 36.26842302083969
# Train Accuracy: 77.778 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 49 ================================
# Epoch Loss: 36.74597664177418
# Train Accuracy: 77.250 %
# Dev Accuracy:  97.000 %
# ================================ Epoch 50 ================================
# Epoch Loss: 35.79809631407261
# Train Accuracy: 77.979 %
# Dev Accuracy:  97.422 %
# ================================ Epoch 51 ================================
# Epoch Loss: 36.646050453186035
# Train Accuracy: 77.556 %
# Dev Accuracy:  97.641 %
# ================================ Epoch 52 ================================
# Epoch Loss: 35.91246089339256
# Train Accuracy: 78.250 %
# Dev Accuracy:  97.547 %
# ================================ Epoch 53 ================================
# Epoch Loss: 36.086931988596916
# Train Accuracy: 77.965 %
# Dev Accuracy:  97.656 %
# ================================ Epoch 54 ================================
# Epoch Loss: 36.45295324921608
# Train Accuracy: 78.035 %
# Dev Accuracy:  97.422 %
# ================================ Epoch 55 ================================
# Epoch Loss: 36.28903067111969
# Train Accuracy: 77.715 %
# Dev Accuracy:  97.844 %
# ================================ Epoch 56 ================================
# Epoch Loss: 36.09328618645668
# Train Accuracy: 77.986 %
# Dev Accuracy:  97.141 %
# ================================ Epoch 57 ================================
# Epoch Loss: 36.51801681518555
# Train Accuracy: 77.403 %
# Dev Accuracy:  97.266 %
# ================================ Epoch 58 ================================
# Epoch Loss: 34.68651704490185
# Train Accuracy: 78.278 %
# Dev Accuracy:  97.422 %
# ================================ Epoch 59 ================================
# Epoch Loss: 35.3446269184351
# Train Accuracy: 78.236 %
# Dev Accuracy:  97.766 %
# ================================ Epoch 60 ================================
# Epoch Loss: 36.2473606467247
# Train Accuracy: 78.104 %
# Dev Accuracy:  97.703 %
# ================================ Epoch 61 ================================
# Epoch Loss: 36.020204707980156
# Train Accuracy: 77.931 %
# Dev Accuracy:  97.562 %
# ================================ Epoch 62 ================================
# Epoch Loss: 36.22091153264046
# Train Accuracy: 78.097 %
# Dev Accuracy:  96.062 %
# ================================ Epoch 63 ================================
# Epoch Loss: 35.68631845712662
# Train Accuracy: 78.160 %
# Dev Accuracy:  97.844 %
# ================================ Epoch 64 ================================
# Epoch Loss: 36.33892756700516
# Train Accuracy: 77.993 %
# Dev Accuracy:  97.672 %
# ================================ Epoch 65 ================================
# Epoch Loss: 35.3406058549881
# Train Accuracy: 78.049 %
# Dev Accuracy:  97.672 %
# ================================ Epoch 66 ================================
# Epoch Loss: 35.62871493399143
# Train Accuracy: 78.250 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 67 ================================
# Epoch Loss: 34.96397340297699
# Train Accuracy: 78.639 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 68 ================================
# Epoch Loss: 34.2567924708128
# Train Accuracy: 78.931 %
# Dev Accuracy:  97.625 %
# ================================ Epoch 69 ================================
# Epoch Loss: 35.43300020694733
# Train Accuracy: 77.951 %
# Dev Accuracy:  96.922 %
# ================================ Epoch 70 ================================
# Epoch Loss: 35.60499222576618
# Train Accuracy: 77.882 %
# Dev Accuracy:  97.609 %
# ================================ Epoch 71 ================================
# Epoch Loss: 35.291996493935585
# Train Accuracy: 78.340 %
# Dev Accuracy:  97.734 %
# ================================ Epoch 72 ================================
# Epoch Loss: 35.40352010726929
# Train Accuracy: 78.208 %
# Dev Accuracy:  97.312 %
# ================================ Epoch 73 ================================
# Epoch Loss: 35.47842238843441
# Train Accuracy: 77.910 %
# Dev Accuracy:  97.734 %
# ================================ Epoch 74 ================================
# Epoch Loss: 36.48485988378525
# Train Accuracy: 77.681 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 75 ================================
# Epoch Loss: 36.21632432937622
# Train Accuracy: 77.660 %
# Dev Accuracy:  97.625 %
# ================================ Epoch 76 ================================
# Epoch Loss: 34.81595516204834
# Train Accuracy: 78.382 %
# Dev Accuracy:  97.266 %
# ================================ Epoch 77 ================================
# Epoch Loss: 35.47861649096012
# Train Accuracy: 78.417 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 78 ================================
# Epoch Loss: 35.16509088873863
# Train Accuracy: 78.444 %
# Dev Accuracy:  97.047 %
# ================================ Epoch 79 ================================
# Epoch Loss: 35.360127955675125
# Train Accuracy: 78.431 %
# Dev Accuracy:  97.547 %
# ================================ Epoch 80 ================================
# Epoch Loss: 34.84684130549431
# Train Accuracy: 77.944 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 81 ================================
# Epoch Loss: 35.054189175367355
# Train Accuracy: 78.403 %
# Dev Accuracy:  96.906 %
# ================================ Epoch 82 ================================
# Epoch Loss: 34.750089943408966
# Train Accuracy: 78.236 %
# Dev Accuracy:  97.594 %
# ================================ Epoch 83 ================================
# Epoch Loss: 35.285350397229195
# Train Accuracy: 78.229 %
# Dev Accuracy:  97.031 %
# ================================ Epoch 84 ================================
# Epoch Loss: 34.7774411290884
# Train Accuracy: 78.688 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 85 ================================
# Epoch Loss: 34.77491554617882
# Train Accuracy: 78.146 %
# Dev Accuracy:  97.047 %
# ================================ Epoch 86 ================================
# Epoch Loss: 34.710332944989204
# Train Accuracy: 78.250 %
# Dev Accuracy:  97.031 %
# ================================ Epoch 87 ================================
# Epoch Loss: 35.36385554075241
# Train Accuracy: 78.410 %
# Dev Accuracy:  97.531 %
# ================================ Epoch 88 ================================
# Epoch Loss: 35.77772618830204
# Train Accuracy: 77.438 %
# Dev Accuracy:  96.875 %
# ================================ Epoch 89 ================================
# Epoch Loss: 35.69578446447849
# Train Accuracy: 78.146 %
# Dev Accuracy:  97.047 %
# ================================ Epoch 90 ================================
# Epoch Loss: 34.585374265909195
# Train Accuracy: 78.583 %
# Dev Accuracy:  97.641 %
# ================================ Epoch 91 ================================
# Epoch Loss: 35.70441600680351
# Train Accuracy: 78.438 %
# Dev Accuracy:  97.141 %
# ================================ Epoch 92 ================================
# Epoch Loss: 34.335622012615204
# Train Accuracy: 78.903 %
# Dev Accuracy:  96.781 %
# ================================ Epoch 93 ================================
# Epoch Loss: 35.34502896666527
# Train Accuracy: 78.104 %
# Dev Accuracy:  97.297 %
# ================================ Epoch 94 ================================
# Epoch Loss: 35.112309679389
# Train Accuracy: 78.299 %
# Dev Accuracy:  96.016 %
# ================================ Epoch 95 ================================
# Epoch Loss: 35.82035046815872
# Train Accuracy: 78.118 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 96 ================================
# Epoch Loss: 35.691463366150856
# Train Accuracy: 77.889 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 97 ================================
# Epoch Loss: 35.67238287627697
# Train Accuracy: 77.833 %
# Dev Accuracy:  97.172 %
# ================================ Epoch 98 ================================
# Epoch Loss: 34.78764793276787
# Train Accuracy: 78.333 %
# Dev Accuracy:  97.266 %
# ================================ Epoch 99 ================================
# Epoch Loss: 35.48089048266411
# Train Accuracy: 78.326 %
# Dev Accuracy:  96.906 %
# ================================ Epoch 100 ================================
# Epoch Loss: 35.07030574977398
# Train Accuracy: 78.194 %
# Dev Accuracy:  97.391 %
# ================================ Epoch 101 ================================
# Epoch Loss: 34.649731889367104
# Train Accuracy: 78.479 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 102 ================================
# Epoch Loss: 34.64468543231487
# Train Accuracy: 78.458 %
# Dev Accuracy:  97.406 %
# ================================ Epoch 103 ================================
# Epoch Loss: 35.02248841524124
# Train Accuracy: 78.458 %
# Dev Accuracy:  96.812 %
# ================================ Epoch 104 ================================
# Epoch Loss: 34.77774657309055
# Train Accuracy: 78.535 %
# Dev Accuracy:  97.203 %
# ================================ Epoch 105 ================================
# Epoch Loss: 35.12643186748028
# Train Accuracy: 78.208 %
# Dev Accuracy:  97.625 %
# ================================ Epoch 106 ================================
# Epoch Loss: 34.53909097611904
# Train Accuracy: 78.778 %
# Dev Accuracy:  97.406 %
# ================================ Epoch 107 ================================
# Epoch Loss: 36.00004920363426
# Train Accuracy: 77.965 %
# Dev Accuracy:  97.234 %
# ================================ Epoch 108 ================================
# Epoch Loss: 35.24382025003433
# Train Accuracy: 78.465 %
# Dev Accuracy:  97.344 %
# ================================ Epoch 109 ================================
# Epoch Loss: 35.28299659490585
# Train Accuracy: 78.208 %
# Dev Accuracy:  97.438 %
# ================================ Epoch 110 ================================
# Epoch Loss: 34.677325963974
# Train Accuracy: 79.021 %
# Dev Accuracy:  97.547 %
# ================================ Epoch 111 ================================
# Epoch Loss: 34.5702068656683
# Train Accuracy: 78.653 %
# Dev Accuracy:  97.297 %
# ================================ Epoch 112 ================================
# Epoch Loss: 35.535848274827
# Train Accuracy: 78.347 %
# Dev Accuracy:  97.109 %
# ================================ Epoch 113 ================================
# Epoch Loss: 34.9786334335804
# Train Accuracy: 78.312 %
# Dev Accuracy:  97.141 %
# ================================ Epoch 114 ================================
# Epoch Loss: 34.56333364546299
# Train Accuracy: 78.160 %
# Dev Accuracy:  97.234 %
# ================================ Epoch 115 ================================
# Epoch Loss: 35.43527355790138
# Train Accuracy: 77.972 %
# Dev Accuracy:  97.609 %
# ================================ Epoch 116 ================================
# Epoch Loss: 35.2840970158577
# Train Accuracy: 77.979 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 117 ================================
# Epoch Loss: 33.820707738399506
# Train Accuracy: 79.049 %
# Dev Accuracy:  97.203 %
# ================================ Epoch 118 ================================
# Epoch Loss: 35.798291981220245
# Train Accuracy: 77.889 %
# Dev Accuracy:  97.156 %
# ================================ Epoch 119 ================================
# Epoch Loss: 34.95558552443981
# Train Accuracy: 78.438 %
# Dev Accuracy:  97.281 %
# ================================ Epoch 120 ================================
# Epoch Loss: 34.82058385014534
# Train Accuracy: 78.271 %
# Dev Accuracy:  96.953 %
# ================================ Epoch 121 ================================
# Epoch Loss: 35.25557292997837
# Train Accuracy: 77.958 %
# Dev Accuracy:  97.094 %
# ================================ Epoch 122 ================================
# Epoch Loss: 35.78766769170761
# Train Accuracy: 78.097 %
# Dev Accuracy:  97.547 %
# ================================ Epoch 123 ================================
# Epoch Loss: 35.6179193854332
# Train Accuracy: 77.896 %
# Dev Accuracy:  96.984 %
# ================================ Epoch 124 ================================
# Epoch Loss: 35.3643666356802
# Train Accuracy: 78.083 %
# Dev Accuracy:  97.156 %
# ================================ Epoch 125 ================================
# Epoch Loss: 34.25427509844303
# Train Accuracy: 78.681 %
# Dev Accuracy:  97.125 %
# ================================ Epoch 126 ================================
# Epoch Loss: 35.32873724400997
# Train Accuracy: 78.660 %
# Dev Accuracy:  96.938 %
# ================================ Epoch 127 ================================
# Epoch Loss: 35.20216244459152
# Train Accuracy: 78.097 %
# Dev Accuracy:  97.594 %
# ================================ Epoch 128 ================================
# Epoch Loss: 35.44071440398693
# Train Accuracy: 77.986 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 129 ================================
# Epoch Loss: 35.110085397958755
# Train Accuracy: 78.090 %
# Dev Accuracy:  96.797 %
# ================================ Epoch 130 ================================
# Epoch Loss: 34.41620500385761
# Train Accuracy: 78.347 %
# Dev Accuracy:  97.500 %
# ================================ Epoch 131 ================================
# Epoch Loss: 34.581020563840866
# Train Accuracy: 78.743 %
# Dev Accuracy:  97.453 %
# ================================ Epoch 132 ================================
# Epoch Loss: 35.41737158596516
# Train Accuracy: 77.861 %
# Dev Accuracy:  97.312 %
# ================================ Epoch 133 ================================
# Epoch Loss: 34.972627371549606
# Train Accuracy: 78.174 %
# Dev Accuracy:  96.438 %
# ================================ Epoch 134 ================================
# Epoch Loss: 36.056140691041946
# Train Accuracy: 77.861 %
# Dev Accuracy:  97.156 %
# ================================ Epoch 135 ================================
# Epoch Loss: 35.9403570741415
# Train Accuracy: 78.174 %
# Dev Accuracy:  97.125 %
# ================================ Epoch 136 ================================
# Epoch Loss: 34.45706197619438
# Train Accuracy: 78.472 %
# Dev Accuracy:  97.266 %
# ================================ Epoch 137 ================================
# Epoch Loss: 34.73192076385021
# Train Accuracy: 78.410 %
# Dev Accuracy:  97.594 %
# ================================ Epoch 138 ================================
# Epoch Loss: 34.74395887553692
# Train Accuracy: 78.556 %
# Dev Accuracy:  97.281 %
# ================================ Epoch 139 ================================
# Epoch Loss: 34.91671173274517
# Train Accuracy: 78.375 %
# Dev Accuracy:  96.891 %
# ================================ Epoch 140 ================================
# Epoch Loss: 35.07238766551018
# Train Accuracy: 78.312 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 141 ================================
# Epoch Loss: 35.52005809545517
# Train Accuracy: 78.250 %
# Dev Accuracy:  97.438 %
# ================================ Epoch 142 ================================
# Epoch Loss: 35.379757061600685
# Train Accuracy: 78.229 %
# Dev Accuracy:  97.625 %
# ================================ Epoch 143 ================================
# Epoch Loss: 34.8735568523407
# Train Accuracy: 78.306 %
# Dev Accuracy:  96.969 %
# ================================ Epoch 144 ================================
# Epoch Loss: 35.359158635139465
# Train Accuracy: 78.000 %
# Dev Accuracy:  97.391 %
# ================================ Epoch 145 ================================
# Epoch Loss: 33.78543059527874
# Train Accuracy: 78.625 %
# Dev Accuracy:  97.672 %
# ================================ Epoch 146 ================================
# Epoch Loss: 34.829530999064445
# Train Accuracy: 78.132 %
# Dev Accuracy:  97.453 %
# ================================ Epoch 147 ================================
# Epoch Loss: 35.351407408714294
# Train Accuracy: 77.896 %
# Dev Accuracy:  97.391 %
# ================================ Epoch 148 ================================
# Epoch Loss: 35.38174459338188
# Train Accuracy: 78.222 %
# Dev Accuracy:  95.516 %
# ================================ Epoch 149 ================================
# Epoch Loss: 34.965612187981606
# Train Accuracy: 78.139 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 150 ================================
# Epoch Loss: 34.541101694107056
# Train Accuracy: 78.896 %
# Dev Accuracy:  96.812 %
# ================================ Epoch 151 ================================
# Epoch Loss: 33.75718420743942
# Train Accuracy: 78.951 %
# Dev Accuracy:  97.172 %
# ================================ Epoch 152 ================================
# Epoch Loss: 34.54380004107952
# Train Accuracy: 78.354 %
# Dev Accuracy:  97.516 %
# ================================ Epoch 153 ================================
# Epoch Loss: 34.867289677262306
# Train Accuracy: 78.229 %
# Dev Accuracy:  97.125 %
# ================================ Epoch 154 ================================
# Epoch Loss: 35.06825989484787
# Train Accuracy: 78.361 %
# Dev Accuracy:  97.094 %
# ================================ Epoch 155 ================================
# Epoch Loss: 34.64865469932556
# Train Accuracy: 78.729 %
# Dev Accuracy:  97.344 %
# ================================ Epoch 156 ================================
# Epoch Loss: 34.75341419875622
# Train Accuracy: 78.229 %
# Dev Accuracy:  97.453 %
# ================================ Epoch 157 ================================
# Epoch Loss: 34.553097024559975
# Train Accuracy: 78.403 %
# Dev Accuracy:  97.203 %
# ================================ Epoch 158 ================================
# Epoch Loss: 35.23323838412762
# Train Accuracy: 77.653 %
# Dev Accuracy:  96.859 %
# ================================ Epoch 159 ================================
# Epoch Loss: 34.90040810406208
# Train Accuracy: 78.333 %
# Dev Accuracy:  97.281 %
# ================================ Epoch 160 ================================
# Epoch Loss: 34.450708493590355
# Train Accuracy: 78.576 %
# Dev Accuracy:  97.312 %
# ================================ Epoch 161 ================================
# Epoch Loss: 34.114879220724106
# Train Accuracy: 78.826 %
# Dev Accuracy:  97.312 %
# ================================ Epoch 162 ================================
# Epoch Loss: 34.38346128165722
# Train Accuracy: 78.403 %
# Dev Accuracy:  97.453 %
# ================================ Epoch 163 ================================
# Epoch Loss: 34.99463413655758
# Train Accuracy: 78.271 %
# Dev Accuracy:  96.750 %
# ================================ Epoch 164 ================================
# Epoch Loss: 35.26615563035011
# Train Accuracy: 78.278 %
# Dev Accuracy:  96.969 %
# ================================ Epoch 165 ================================
# Epoch Loss: 35.39341761171818
# Train Accuracy: 78.222 %
# Dev Accuracy:  97.156 %
# ================================ Epoch 166 ================================
# Epoch Loss: 35.52252113819122
# Train Accuracy: 77.910 %
# Dev Accuracy:  96.719 %
# ================================ Epoch 167 ================================
# Epoch Loss: 34.72291845083237
# Train Accuracy: 78.340 %
# Dev Accuracy:  96.719 %
# ================================ Epoch 168 ================================
# Epoch Loss: 34.53455236554146
# Train Accuracy: 78.431 %
# Dev Accuracy:  97.031 %
# ================================ Epoch 169 ================================
# Epoch Loss: 34.93566153943539
# Train Accuracy: 78.208 %
# Dev Accuracy:  97.172 %
# ================================ Epoch 170 ================================
# Epoch Loss: 34.80400836467743
# Train Accuracy: 78.500 %
# Dev Accuracy:  97.078 %
# ================================ Epoch 171 ================================
# Epoch Loss: 34.64408351480961
# Train Accuracy: 77.917 %
# Dev Accuracy:  97.203 %
# ================================ Epoch 172 ================================
# Epoch Loss: 34.559884414076805
# Train Accuracy: 78.340 %
# Dev Accuracy:  97.453 %
# ================================ Epoch 173 ================================
# Epoch Loss: 34.290739342570305
# Train Accuracy: 78.569 %
# Dev Accuracy:  97.625 %
# ================================ Epoch 174 ================================
# Epoch Loss: 34.97816751897335
# Train Accuracy: 78.306 %
# Dev Accuracy:  96.922 %
# ================================ Epoch 175 ================================
# Epoch Loss: 34.676520615816116
# Train Accuracy: 78.250 %
# Dev Accuracy:  97.406 %
# ================================ Epoch 176 ================================
# Epoch Loss: 34.68298149108887
# Train Accuracy: 78.257 %
# Dev Accuracy:  97.109 %
# ================================ Epoch 177 ================================
# Epoch Loss: 34.31219120323658
# Train Accuracy: 78.750 %
# Dev Accuracy:  96.812 %
# ================================ Epoch 178 ================================
# Epoch Loss: 34.25449565052986
# Train Accuracy: 78.764 %
# Dev Accuracy:  96.812 %
# ================================ Epoch 179 ================================
# Epoch Loss: 35.522969990968704
# Train Accuracy: 77.993 %
# Dev Accuracy:  97.297 %
# ================================ Epoch 180 ================================
# Epoch Loss: 33.81326821446419
# Train Accuracy: 79.243 %
# Dev Accuracy:  97.625 %
# ================================ Epoch 181 ================================
# Epoch Loss: 34.6937991976738
# Train Accuracy: 78.597 %
# Dev Accuracy:  97.234 %
# ================================ Epoch 182 ================================
# Epoch Loss: 34.79123552143574
# Train Accuracy: 78.472 %
# Dev Accuracy:  97.047 %
# ================================ Epoch 183 ================================
# Epoch Loss: 35.02428974211216
# Train Accuracy: 78.326 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 184 ================================
# Epoch Loss: 34.85695689916611
# Train Accuracy: 78.278 %
# Dev Accuracy:  97.156 %
# ================================ Epoch 185 ================================
# Epoch Loss: 35.00721162557602
# Train Accuracy: 78.035 %
# Dev Accuracy:  96.906 %
# ================================ Epoch 186 ================================
# Epoch Loss: 34.639735251665115
# Train Accuracy: 78.312 %
# Dev Accuracy:  97.141 %
# ================================ Epoch 187 ================================
# Epoch Loss: 34.812103033065796
# Train Accuracy: 78.111 %
# Dev Accuracy:  97.391 %
# ================================ Epoch 188 ================================
# Epoch Loss: 34.84629549086094
# Train Accuracy: 78.528 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 189 ================================
# Epoch Loss: 33.87599238753319
# Train Accuracy: 78.833 %
# Dev Accuracy:  97.531 %
# ================================ Epoch 190 ================================
# Epoch Loss: 34.36034815013409
# Train Accuracy: 78.104 %
# Dev Accuracy:  97.594 %
# ================================ Epoch 191 ================================
# Epoch Loss: 34.69194258749485
# Train Accuracy: 78.292 %
# Dev Accuracy:  96.688 %
# ================================ Epoch 192 ================================
# Epoch Loss: 33.96072016656399
# Train Accuracy: 78.771 %
# Dev Accuracy:  97.500 %
# ================================ Epoch 193 ================================
# Epoch Loss: 34.72740399837494
# Train Accuracy: 78.326 %
# Dev Accuracy:  97.172 %
# ================================ Epoch 194 ================================
# Epoch Loss: 35.41677229106426
# Train Accuracy: 77.993 %
# Dev Accuracy:  97.406 %
# ================================ Epoch 195 ================================
# Epoch Loss: 35.03275911509991
# Train Accuracy: 78.104 %
# Dev Accuracy:  97.281 %
# ================================ Epoch 196 ================================
# Epoch Loss: 34.356199115514755
# Train Accuracy: 78.312 %
# Dev Accuracy:  97.125 %
# ================================ Epoch 197 ================================
# Epoch Loss: 34.022428289055824
# Train Accuracy: 78.722 %
# Dev Accuracy:  96.719 %
# ================================ Epoch 198 ================================
# Epoch Loss: 34.47173322737217
# Train Accuracy: 78.299 %
# Dev Accuracy:  96.953 %
# ================================ Epoch 199 ================================
# Epoch Loss: 34.53465083241463
# Train Accuracy: 78.222 %
# Dev Accuracy:  97.094 %
# ================================ Epoch 200 ================================
# Epoch Loss: 34.200371503829956
# Train Accuracy: 78.653 %
# Dev Accuracy:  97.391 %
# ================================ Epoch 201 ================================
# Epoch Loss: 34.979182347655296
# Train Accuracy: 77.993 %
# Dev Accuracy:  96.859 %
# ================================ Epoch 202 ================================
# Epoch Loss: 34.962216675281525
# Train Accuracy: 78.312 %
# Dev Accuracy:  96.797 %
# ================================ Epoch 203 ================================
# Epoch Loss: 34.68962441384792
# Train Accuracy: 78.174 %
# Dev Accuracy:  97.000 %
# ================================ Epoch 204 ================================
# Epoch Loss: 34.701713129878044
# Train Accuracy: 78.812 %
# Dev Accuracy:  96.875 %
# ================================ Epoch 205 ================================
# Epoch Loss: 34.481119841337204
# Train Accuracy: 78.326 %
# Dev Accuracy:  97.375 %
# ================================ Epoch 206 ================================
# Epoch Loss: 34.72026492655277
# Train Accuracy: 78.201 %
# Dev Accuracy:  96.641 %
# ================================ Epoch 207 ================================
# Epoch Loss: 34.887377589941025
# Train Accuracy: 78.382 %
# Dev Accuracy:  97.531 %
# ================================ Epoch 208 ================================
# Epoch Loss: 35.10479734838009
# Train Accuracy: 78.278 %
# Dev Accuracy:  97.094 %
# ================================ Epoch 209 ================================
# Epoch Loss: 34.845295920968056
# Train Accuracy: 78.778 %
# Dev Accuracy:  97.406 %
# ================================ Epoch 210 ================================
# Epoch Loss: 35.37876237928867
# Train Accuracy: 78.181 %
# Dev Accuracy:  97.375 %
# ================================ Epoch 211 ================================
# Epoch Loss: 33.969150856137276
# Train Accuracy: 78.722 %
# Dev Accuracy:  97.094 %
# ================================ Epoch 212 ================================
# Epoch Loss: 33.768071219325066
# Train Accuracy: 79.361 %
# Dev Accuracy:  97.766 %
# ================================ Epoch 213 ================================
# Epoch Loss: 35.05923664569855
# Train Accuracy: 78.410 %
# Dev Accuracy:  97.250 %
# ================================ Epoch 214 ================================
# Epoch Loss: 34.5302589982748
# Train Accuracy: 78.528 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 215 ================================
# Epoch Loss: 34.036911845207214
# Train Accuracy: 78.875 %
# Dev Accuracy:  97.062 %
# ================================ Epoch 216 ================================
# Epoch Loss: 34.67650832235813
# Train Accuracy: 78.576 %
# Dev Accuracy:  96.781 %
# ================================ Epoch 217 ================================
# Epoch Loss: 34.50656180083752
# Train Accuracy: 78.306 %
# Dev Accuracy:  97.297 %
# ================================ Epoch 218 ================================
# Epoch Loss: 35.19046987593174
# Train Accuracy: 78.583 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 219 ================================
# Epoch Loss: 34.618679478764534
# Train Accuracy: 78.410 %
# Dev Accuracy:  96.922 %
# ================================ Epoch 220 ================================
# Epoch Loss: 34.14004594087601
# Train Accuracy: 78.681 %
# Dev Accuracy:  97.562 %
# ================================ Epoch 221 ================================
# Epoch Loss: 35.00588294863701
# Train Accuracy: 78.354 %
# Dev Accuracy:  96.969 %
# ================================ Epoch 222 ================================
# Epoch Loss: 34.30024002492428
# Train Accuracy: 78.688 %
# Dev Accuracy:  97.141 %
# ================================ Epoch 223 ================================
# Epoch Loss: 34.99583901464939
# Train Accuracy: 78.382 %
# Dev Accuracy:  96.688 %
# ================================ Epoch 224 ================================
# Epoch Loss: 34.13876397907734
# Train Accuracy: 78.778 %
# Dev Accuracy:  97.188 %
# ================================ Epoch 225 ================================
# Epoch Loss: 34.00120586156845
# Train Accuracy: 78.833 %
# Dev Accuracy:  96.562 %
# ================================ Epoch 226 ================================
# Epoch Loss: 33.99025931954384
# Train Accuracy: 79.264 %
# Dev Accuracy:  97.234 %
# ================================ Epoch 227 ================================
# Epoch Loss: 35.253173872828484
# Train Accuracy: 78.062 %
# Dev Accuracy:  97.359 %
# ================================ Epoch 228 ================================
# Epoch Loss: 34.90766167640686
# Train Accuracy: 78.201 %
# Dev Accuracy:  97.016 %
# ================================ Epoch 229 ================================
# Epoch Loss: 34.28606928884983
# Train Accuracy: 78.667 %
# Dev Accuracy:  96.969 %
# ================================ Epoch 230 ================================
# Epoch Loss: 34.62652951478958
# Train Accuracy: 78.618 %
# Dev Accuracy:  97.094 %
# ================================ Epoch 231 ================================
# Epoch Loss: 34.57061818242073
# Train Accuracy: 78.319 %
# Dev Accuracy:  97.203 %
# ================================ Epoch 232 ================================
# Epoch Loss: 33.44768327474594
# Train Accuracy: 79.243 %
# Dev Accuracy:  97.328 %
# ================================ Epoch 233 ================================
# Epoch Loss: 34.25748735666275
# Train Accuracy: 78.542 %
# Dev Accuracy:  97.234 %
# ================================ Epoch 234 ================================
# Epoch Loss: 34.851658284664154
# Train Accuracy: 77.958 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 235 ================================
# Epoch Loss: 34.89417764544487
# Train Accuracy: 78.549 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 236 ================================
# Epoch Loss: 34.12150597572327
# Train Accuracy: 78.618 %
# Dev Accuracy:  97.000 %
# ================================ Epoch 237 ================================
# Epoch Loss: 34.122275710105896
# Train Accuracy: 78.299 %
# Dev Accuracy:  96.469 %
# ================================ Epoch 238 ================================
# Epoch Loss: 34.10275821387768
# Train Accuracy: 78.403 %
# Dev Accuracy:  97.125 %
# ================================ Epoch 239 ================================
# Epoch Loss: 34.50718170404434
# Train Accuracy: 78.465 %
# Dev Accuracy:  97.000 %
# ================================ Epoch 240 ================================
# Epoch Loss: 35.673805713653564
# Train Accuracy: 77.861 %
# Dev Accuracy:  97.031 %
# ================================ Epoch 241 ================================
# Epoch Loss: 35.49841034412384
# Train Accuracy: 77.882 %
# Dev Accuracy:  97.219 %
# ================================ Epoch 242 ================================
# Epoch Loss: 34.27858057618141
# Train Accuracy: 78.333 %
# Dev Accuracy:  97.141 %
# ================================ Epoch 243 ================================
# Epoch Loss: 34.01142743229866
# Train Accuracy: 78.660 %
# Dev Accuracy:  96.859 %
# ================================ Epoch 244 ================================
# Epoch Loss: 34.653497114777565
# Train Accuracy: 78.056 %
# Dev Accuracy:  96.969 %
# ================================ Epoch 245 ================================
# Epoch Loss: 34.08529897034168
# Train Accuracy: 78.868 %
# Dev Accuracy:  97.297 %
# ================================ Epoch 246 ================================
# Epoch Loss: 34.192878261208534
# Train Accuracy: 78.472 %
# Dev Accuracy:  96.938 %
# ================================ Epoch 247 ================================
# Epoch Loss: 35.289825424551964
# Train Accuracy: 78.139 %
# Dev Accuracy:  96.719 %
# ================================ Epoch 248 ================================
# Epoch Loss: 36.979024559259415
# Train Accuracy: 77.847 %
# Dev Accuracy:  96.734 %
# ================================ Epoch 249 ================================
# Epoch Loss: 36.67619377374649
# Train Accuracy: 77.410 %
# Dev Accuracy:  97.062 %
# ================================ Epoch 250 ================================
# Epoch Loss: 35.501794546842575
# Train Accuracy: 77.986 %
# Dev Accuracy:  97.156 %

# %%
torch.save(model.state_dict(), 'BERT-FND.pth')
